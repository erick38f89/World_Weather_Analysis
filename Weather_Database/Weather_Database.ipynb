# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Get the nearest city using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, add to the cities.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 760

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | maloy
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | umm kaddadah
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | nortelandia
# Processing Record 8 of Set 1 | upington
# Processing Record 9 of Set 1 | walvis bay
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | erenhot
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | gore
# Processing Record 19 of Set 1 | qui nhon
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | port-gentil
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | omsukchan
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | goderich
# Processing Record 30 of Set 1 | moerai
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | barcelos
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | enterprise
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | buedu
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | gweta
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | maniitsoq
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | hirara
# Processing Record 48 of Set 1 | zolotinka
# City not found. Skipping...
# Processing Record 49 of Set 1 | brahmapuri
# City not found. Skipping...
# Processing Record 50 of Set 1 | trincomalee
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | vila
# Processing Record 4 of Set 2 | caribou
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | ponta delgada
# Processing Record 7 of Set 2 | gaogou
# Processing Record 8 of Set 2 | doong
# Processing Record 9 of Set 2 | half moon bay
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | salalah
# Processing Record 12 of Set 2 | saint-pierre
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | pinega
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | kieta
# Processing Record 18 of Set 2 | bure
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | umm lajj
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | nome
# Processing Record 25 of Set 2 | aykhal
# Processing Record 26 of Set 2 | namwala
# Processing Record 27 of Set 2 | brae
# Processing Record 28 of Set 2 | port hueneme
# Processing Record 29 of Set 2 | sarapul
# Processing Record 30 of Set 2 | xadani
# City not found. Skipping...
# Processing Record 31 of Set 2 | gizo
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | richards bay
# Processing Record 34 of Set 2 | castrillon
# Processing Record 35 of Set 2 | qaqortoq
# Processing Record 36 of Set 2 | alekseyevsk
# Processing Record 37 of Set 2 | changji
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | fulton
# Processing Record 41 of Set 2 | nabire
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | annau
# Processing Record 45 of Set 2 | honningsvag
# Processing Record 46 of Set 2 | thayetmyo
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | mount gambier
# Processing Record 49 of Set 2 | jishou
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | andenes
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | salinopolis
# Processing Record 4 of Set 3 | bulungu
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | baracoa
# Processing Record 7 of Set 3 | santa maria
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | broken hill
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | lerwick
# Processing Record 13 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | doha
# Processing Record 18 of Set 3 | weligama
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | bela
# Processing Record 21 of Set 3 | taoudenni
# Processing Record 22 of Set 3 | dzerzhinskoye
# Processing Record 23 of Set 3 | nara
# Processing Record 24 of Set 3 | paracatu
# Processing Record 25 of Set 3 | mandalgovi
# Processing Record 26 of Set 3 | ahipara
# Processing Record 27 of Set 3 | santa ana
# Processing Record 28 of Set 3 | samarai
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | adolfo lopez mateos
# Processing Record 32 of Set 3 | lamu
# Processing Record 33 of Set 3 | puerto madryn
# Processing Record 34 of Set 3 | salisbury
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | kawai
# Processing Record 37 of Set 3 | jieshi
# Processing Record 38 of Set 3 | athabasca
# Processing Record 39 of Set 3 | kasempa
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | yei
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | acari
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | manubul
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | san sebastian
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | coihaique
# Processing Record 3 of Set 4 | meridian
# Processing Record 4 of Set 4 | libertador general san martin
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | kolvereid
# Processing Record 8 of Set 4 | high prairie
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | natal
# Processing Record 11 of Set 4 | kralendijk
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | posadas
# Processing Record 16 of Set 4 | portoferraio
# Processing Record 17 of Set 4 | ponnani
# Processing Record 18 of Set 4 | monmouth
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | north bend
# Processing Record 22 of Set 4 | yarada
# Processing Record 23 of Set 4 | baruun-urt
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | vaini
# Processing Record 27 of Set 4 | sondrio
# Processing Record 28 of Set 4 | lasa
# Processing Record 29 of Set 4 | winnemucca
# Processing Record 30 of Set 4 | namibe
# Processing Record 31 of Set 4 | fortuna
# Processing Record 32 of Set 4 | kahului
# Processing Record 33 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | muroran
# Processing Record 36 of Set 4 | mehamn
# Processing Record 37 of Set 4 | itea
# Processing Record 38 of Set 4 | sioux lookout
# Processing Record 39 of Set 4 | ostrovnoy
# Processing Record 40 of Set 4 | havoysund
# Processing Record 41 of Set 4 | fuzhou
# Processing Record 42 of Set 4 | sal rei
# Processing Record 43 of Set 4 | wagar
# Processing Record 44 of Set 4 | ketchikan
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | nalut
# Processing Record 47 of Set 4 | terra santa
# Processing Record 48 of Set 4 | sherpur
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | blind river
# Processing Record 1 of Set 5 | buraydah
# Processing Record 2 of Set 5 | plettenberg bay
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | atbasar
# Processing Record 6 of Set 5 | irbeyskoye
# Processing Record 7 of Set 5 | abay
# Processing Record 8 of Set 5 | paamiut
# Processing Record 9 of Set 5 | sola
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | rundu
# Processing Record 12 of Set 5 | craig
# Processing Record 13 of Set 5 | juybar
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | asau
# Processing Record 16 of Set 5 | garmsar
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | denpasar
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | saint-augustin
# Processing Record 21 of Set 5 | kyrksaeterora
# Processing Record 22 of Set 5 | pangai
# Processing Record 23 of Set 5 | salym
# Processing Record 24 of Set 5 | wamba
# Processing Record 25 of Set 5 | santa isabel do rio negro
# Processing Record 26 of Set 5 | poopo
# Processing Record 27 of Set 5 | haines junction
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | lebanon
# Processing Record 30 of Set 5 | hasaki
# Processing Record 31 of Set 5 | baykit
# Processing Record 32 of Set 5 | batemans bay
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | newcastle
# Processing Record 37 of Set 5 | nantucket
# Processing Record 38 of Set 5 | madison
# Processing Record 39 of Set 5 | itoman
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | urbano santos
# Processing Record 42 of Set 5 | oranjemund
# Processing Record 43 of Set 5 | zhigansk
# Processing Record 44 of Set 5 | tuktoyaktuk
# Processing Record 45 of Set 5 | luan
# Processing Record 46 of Set 5 | koumac
# Processing Record 47 of Set 5 | amazar
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | northam
# Processing Record 50 of Set 5 | znamenka
# Processing Record 1 of Set 6 | rosbach
# Processing Record 2 of Set 6 | martapura
# Processing Record 3 of Set 6 | basoko
# Processing Record 4 of Set 6 | maragogi
# Processing Record 5 of Set 6 | woodward
# Processing Record 6 of Set 6 | pingliang
# Processing Record 7 of Set 6 | quatre cocos
# Processing Record 8 of Set 6 | hualmay
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | isilkul
# Processing Record 12 of Set 6 | fort walton beach
# Processing Record 13 of Set 6 | lomas de sargentillo
# Processing Record 14 of Set 6 | empa
# City not found. Skipping...
# Processing Record 15 of Set 6 | yelizovo
# Processing Record 16 of Set 6 | daru
# Processing Record 17 of Set 6 | matamoros
# Processing Record 18 of Set 6 | manokwari
# Processing Record 19 of Set 6 | los negros
# Processing Record 20 of Set 6 | opuwo
# Processing Record 21 of Set 6 | brigantine
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | saint-gaudens
# Processing Record 24 of Set 6 | chikwawa
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | luwuk
# Processing Record 27 of Set 6 | matara
# Processing Record 28 of Set 6 | saint-philippe
# Processing Record 29 of Set 6 | tornio
# Processing Record 30 of Set 6 | benguela
# Processing Record 31 of Set 6 | mwinilunga
# Processing Record 32 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 6 | payyannur
# Processing Record 34 of Set 6 | kununurra
# Processing Record 35 of Set 6 | imeni poliny osipenko
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | tautira
# Processing Record 38 of Set 6 | grand-lahou
# Processing Record 39 of Set 6 | bowen
# Processing Record 40 of Set 6 | hailar
# Processing Record 41 of Set 6 | norcasia
# Processing Record 42 of Set 6 | yaan
# Processing Record 43 of Set 6 | hella
# Processing Record 44 of Set 6 | miles city
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | russell
# Processing Record 47 of Set 6 | muromtsevo
# Processing Record 48 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 6 | iquitos
# Processing Record 50 of Set 6 | severo-kurilsk
# Processing Record 1 of Set 7 | amahai
# Processing Record 2 of Set 7 | san marcos
# Processing Record 3 of Set 7 | machico
# Processing Record 4 of Set 7 | shimoda
# Processing Record 5 of Set 7 | koroni
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 8 of Set 7 | kirakira
# Processing Record 9 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 7 | danilov
# Processing Record 11 of Set 7 | upata
# Processing Record 12 of Set 7 | staritsa
# Processing Record 13 of Set 7 | birao
# Processing Record 14 of Set 7 | camacha
# Processing Record 15 of Set 7 | katangli
# Processing Record 16 of Set 7 | lingao
# Processing Record 17 of Set 7 | killybegs
# Processing Record 18 of Set 7 | atikokan
# Processing Record 19 of Set 7 | thunder bay
# Processing Record 20 of Set 7 | birjand
# Processing Record 21 of Set 7 | skjervoy
# Processing Record 22 of Set 7 | avera
# Processing Record 23 of Set 7 | awjilah
# Processing Record 24 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 7 | chimoio
# Processing Record 26 of Set 7 | nykobing
# City not found. Skipping...
# Processing Record 27 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 7 | grenada
# Processing Record 29 of Set 7 | saint-joseph
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | vitim
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 7 | chokurdakh
# Processing Record 35 of Set 7 | ust-kalmanka
# Processing Record 36 of Set 7 | hami
# Processing Record 37 of Set 7 | rockport
# Processing Record 38 of Set 7 | karratha
# Processing Record 39 of Set 7 | baghdad
# Processing Record 40 of Set 7 | san andres
# Processing Record 41 of Set 7 | atar
# Processing Record 42 of Set 7 | ponta pora
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | peno
# Processing Record 46 of Set 7 | alindao
# Processing Record 47 of Set 7 | owando
# Processing Record 48 of Set 7 | straumen
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | harper
# Processing Record 1 of Set 8 | vestmannaeyjar
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | tangier
# Processing Record 4 of Set 8 | los alamos
# Processing Record 5 of Set 8 | portland
# Processing Record 6 of Set 8 | pampa
# Processing Record 7 of Set 8 | matagami
# Processing Record 8 of Set 8 | vreed en hoop
# City not found. Skipping...
# Processing Record 9 of Set 8 | ewa beach
# Processing Record 10 of Set 8 | mar del plata
# Processing Record 11 of Set 8 | chuy
# Processing Record 12 of Set 8 | port augusta
# Processing Record 13 of Set 8 | chicama
# Processing Record 14 of Set 8 | ulaangom
# Processing Record 15 of Set 8 | kamaishi
# Processing Record 16 of Set 8 | filadelfia
# Processing Record 17 of Set 8 | huanren
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | tan an
# Processing Record 20 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 8 | ahuimanu
# Processing Record 22 of Set 8 | cherskiy
# Processing Record 23 of Set 8 | pinheiro machado
# Processing Record 24 of Set 8 | tahoua
# Processing Record 25 of Set 8 | karpogory
# Processing Record 26 of Set 8 | tuatapere
# Processing Record 27 of Set 8 | sao gabriel da cachoeira
# Processing Record 28 of Set 8 | novikovo
# Processing Record 29 of Set 8 | ucluelet
# Processing Record 30 of Set 8 | paragominas
# Processing Record 31 of Set 8 | rotenburg
# Processing Record 32 of Set 8 | aswan
# Processing Record 33 of Set 8 | rocha
# Processing Record 34 of Set 8 | simbahan
# Processing Record 35 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | windsor
# Processing Record 40 of Set 8 | kokstad
# Processing Record 41 of Set 8 | bengkulu
# Processing Record 42 of Set 8 | douglas
# Processing Record 43 of Set 8 | srivardhan
# Processing Record 44 of Set 8 | caravelas
# Processing Record 45 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 8 | naze
# Processing Record 47 of Set 8 | seoul
# Processing Record 48 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 49 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 8 | jutai
# Processing Record 1 of Set 9 | likhoslavl
# Processing Record 2 of Set 9 | ambon
# Processing Record 3 of Set 9 | beloha
# Processing Record 4 of Set 9 | tecoanapa
# Processing Record 5 of Set 9 | paracuru
# Processing Record 6 of Set 9 | urambo
# Processing Record 7 of Set 9 | saurimo
# Processing Record 8 of Set 9 | svetlaya
# Processing Record 9 of Set 9 | aneza
# Processing Record 10 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 9 | kropotkin
# Processing Record 12 of Set 9 | agropoli
# Processing Record 13 of Set 9 | sampit
# Processing Record 14 of Set 9 | luancheng
# Processing Record 15 of Set 9 | hovd
# Processing Record 16 of Set 9 | santa marta
# Processing Record 17 of Set 9 | kasongo-lunda
# Processing Record 18 of Set 9 | shelburne
# Processing Record 19 of Set 9 | dunajska streda
# Processing Record 20 of Set 9 | cockburn town
# Processing Record 21 of Set 9 | vestmanna
# Processing Record 22 of Set 9 | seymchan
# Processing Record 23 of Set 9 | katherine
# Processing Record 24 of Set 9 | la ronge
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | ndioum
# Processing Record 27 of Set 9 | saint anthony
# Processing Record 28 of Set 9 | popondetta
# Processing Record 29 of Set 9 | vostochnyy
# Processing Record 30 of Set 9 | xuddur
# Processing Record 31 of Set 9 | warmbad
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | poum
# Processing Record 34 of Set 9 | atambua
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 9 | barra patuca
# Processing Record 37 of Set 9 | mount isa
# Processing Record 38 of Set 9 | tutoia
# Processing Record 39 of Set 9 | keningau
# Processing Record 40 of Set 9 | coahuayana
# Processing Record 41 of Set 9 | snezhnogorsk
# Processing Record 42 of Set 9 | necochea
# Processing Record 43 of Set 9 | mtimbira
# Processing Record 44 of Set 9 | bonthe
# Processing Record 45 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 9 | leshukonskoye
# Processing Record 47 of Set 9 | olafsvik
# Processing Record 48 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 9 | cam ranh
# Processing Record 50 of Set 9 | warwick
# Processing Record 1 of Set 10 | ilhabela
# Processing Record 2 of Set 10 | cochrane
# Processing Record 3 of Set 10 | evensk
# Processing Record 4 of Set 10 | lompoc
# Processing Record 5 of Set 10 | bethanien
# Processing Record 6 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 7 of Set 10 | poso
# Processing Record 8 of Set 10 | pasni
# Processing Record 9 of Set 10 | victor harbor
# Processing Record 10 of Set 10 | mangan
# Processing Record 11 of Set 10 | ruteng
# Processing Record 12 of Set 10 | caohai
# Processing Record 13 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 15 of Set 10 | krasnoarmeysk
# Processing Record 16 of Set 10 | george
# Processing Record 17 of Set 10 | darhan
# Processing Record 18 of Set 10 | texarkana
# Processing Record 19 of Set 10 | jozefow
# Processing Record 20 of Set 10 | mayumba
# Processing Record 21 of Set 10 | rabaul
# Processing Record 22 of Set 10 | kizukuri
# Processing Record 23 of Set 10 | dingle
# Processing Record 24 of Set 10 | imbituba
# Processing Record 25 of Set 10 | verkhnyaya inta
# Processing Record 26 of Set 10 | amapa
# Processing Record 27 of Set 10 | morondava
# Processing Record 28 of Set 10 | cotonou
# Processing Record 29 of Set 10 | tuxpan
# Processing Record 30 of Set 10 | yeppoon
# Processing Record 31 of Set 10 | lata
# Processing Record 32 of Set 10 | kodinsk
# Processing Record 33 of Set 10 | tamiahua
# Processing Record 34 of Set 10 | bandarbeyla
# Processing Record 35 of Set 10 | chutung
# City not found. Skipping...
# Processing Record 36 of Set 10 | gondar
# Processing Record 37 of Set 10 | los llanos de aridane
# Processing Record 38 of Set 10 | alzamay
# Processing Record 39 of Set 10 | muana
# Processing Record 40 of Set 10 | carnarvon
# Processing Record 41 of Set 10 | kiruna
# Processing Record 42 of Set 10 | inirida
# Processing Record 43 of Set 10 | rincon
# Processing Record 44 of Set 10 | chegdomyn
# Processing Record 45 of Set 10 | veraval
# Processing Record 46 of Set 10 | khuzhir
# Processing Record 47 of Set 10 | tezu
# Processing Record 48 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 10 | tual
# Processing Record 50 of Set 10 | manzil salim
# Processing Record 1 of Set 11 | gazojak
# Processing Record 2 of Set 11 | aksarka
# Processing Record 3 of Set 11 | kudahuvadhoo
# Processing Record 4 of Set 11 | andros town
# Processing Record 5 of Set 11 | disna
# Processing Record 6 of Set 11 | axim
# Processing Record 7 of Set 11 | vila franca do campo
# Processing Record 8 of Set 11 | kaura namoda
# Processing Record 9 of Set 11 | cidreira
# Processing Record 10 of Set 11 | meulaboh
# Processing Record 11 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 11 | acapulco
# Processing Record 13 of Set 11 | nepalganj
# City not found. Skipping...
# Processing Record 14 of Set 11 | manaure
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | pedasi
# Processing Record 17 of Set 11 | dibulla
# Processing Record 18 of Set 11 | piacabucu
# Processing Record 19 of Set 11 | taltal
# Processing Record 20 of Set 11 | kutum
# Processing Record 21 of Set 11 | pitimbu
# Processing Record 22 of Set 11 | magadan
# Processing Record 23 of Set 11 | odienne
# Processing Record 24 of Set 11 | vrangel
# Processing Record 25 of Set 11 | cortez
# Processing Record 26 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 11 | sitka
# Processing Record 28 of Set 11 | ixtapa
# Processing Record 29 of Set 11 | sirisia
# City not found. Skipping...
# Processing Record 30 of Set 11 | hofn
# Processing Record 31 of Set 11 | englewood
# Processing Record 32 of Set 11 | waipawa
# Processing Record 33 of Set 11 | strezhevoy
# Processing Record 34 of Set 11 | bogorodskoye
# Processing Record 35 of Set 11 | qianguo
# Processing Record 36 of Set 11 | buin
# Processing Record 37 of Set 11 | sidi qasim
# City not found. Skipping...
# Processing Record 38 of Set 11 | autun
# Processing Record 39 of Set 11 | bell ville
# Processing Record 40 of Set 11 | kattivakkam
# Processing Record 41 of Set 11 | tabas
# Processing Record 42 of Set 11 | rosarito
# Processing Record 43 of Set 11 | sao miguel do araguaia
# Processing Record 44 of Set 11 | viedma
# Processing Record 45 of Set 11 | mogadishu
# Processing Record 46 of Set 11 | sorong
# Processing Record 47 of Set 11 | milkovo
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | the valley
# Processing Record 50 of Set 11 | miyang
# Processing Record 1 of Set 12 | colon
# Processing Record 2 of Set 12 | asosa
# Processing Record 3 of Set 12 | pompeia
# Processing Record 4 of Set 12 | grand gaube
# Processing Record 5 of Set 12 | indianola
# Processing Record 6 of Set 12 | tucurui
# Processing Record 7 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 8 of Set 12 | palmer
# Processing Record 9 of Set 12 | jiuquan
# Processing Record 10 of Set 12 | bastia
# Processing Record 11 of Set 12 | puerto leguizamo
# Processing Record 12 of Set 12 | mitsamiouli
# Processing Record 13 of Set 12 | ormara
# Processing Record 14 of Set 12 | marshfield
# Processing Record 15 of Set 12 | quang ngai
# Processing Record 16 of Set 12 | husavik
# Processing Record 17 of Set 12 | port lincoln
# Processing Record 18 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 12 | kavkazskiy
# Processing Record 20 of Set 12 | leningradskiy
# Processing Record 21 of Set 12 | chaplynka
# Processing Record 22 of Set 12 | sao joao da barra
# Processing Record 23 of Set 12 | yumen
# Processing Record 24 of Set 12 | villa carlos paz
# Processing Record 25 of Set 12 | sombrio
# Processing Record 26 of Set 12 | kailua
# Processing Record 27 of Set 12 | mvangue
# Processing Record 28 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 12 | great falls
# Processing Record 30 of Set 12 | daman
# Processing Record 31 of Set 12 | kuusankoski
# Processing Record 32 of Set 12 | trelew
# Processing Record 33 of Set 12 | erzin
# Processing Record 34 of Set 12 | tarakan
# Processing Record 35 of Set 12 | kondapalle
# Processing Record 36 of Set 12 | sechura
# Processing Record 37 of Set 12 | unguia
# Processing Record 38 of Set 12 | tanete
# Processing Record 39 of Set 12 | senneterre
# Processing Record 40 of Set 12 | hamilton
# Processing Record 41 of Set 12 | cumberland
# Processing Record 42 of Set 12 | shamli
# Processing Record 43 of Set 12 | cayenne
# Processing Record 44 of Set 12 | sawakin
# Processing Record 45 of Set 12 | honiara
# Processing Record 46 of Set 12 | krokos
# Processing Record 47 of Set 12 | duluth
# Processing Record 48 of Set 12 | deniliquin
# Processing Record 49 of Set 12 | zerbst
# Processing Record 50 of Set 12 | machiques
# Processing Record 1 of Set 13 | pandan
# Processing Record 2 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 3 of Set 13 | wampusirpi
# City not found. Skipping...
# Processing Record 4 of Set 13 | villarrica
# Processing Record 5 of Set 13 | aripuana
# Processing Record 6 of Set 13 | lieksa
# Processing Record 7 of Set 13 | labuhan
# Processing Record 8 of Set 13 | chaozhou
# Processing Record 9 of Set 13 | tevaitoa
# Processing Record 10 of Set 13 | wajir
# Processing Record 11 of Set 13 | sorland
# Processing Record 12 of Set 13 | eldorado
# Processing Record 13 of Set 13 | primorsk
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | bol
# Processing Record 16 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 13 | esso
# Processing Record 18 of Set 13 | verkh-neyvinskiy
# Processing Record 19 of Set 13 | kloulklubed
# Processing Record 20 of Set 13 | cairns
# Processing Record 21 of Set 13 | tadine
# Processing Record 22 of Set 13 | havre
# Processing Record 23 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 13 | kulhudhuffushi
# Processing Record 25 of Set 13 | siolim
# City not found. Skipping...
# Processing Record 26 of Set 13 | tuy hoa
# Processing Record 27 of Set 13 | booue
# Processing Record 28 of Set 13 | saalfelden
# City not found. Skipping...
# Processing Record 29 of Set 13 | egvekinot
# Processing Record 30 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 13 | bilma
# Processing Record 32 of Set 13 | sindou
# Processing Record 33 of Set 13 | corrente
# Processing Record 34 of Set 13 | broome
# Processing Record 35 of Set 13 | tarauaca
# Processing Record 36 of Set 13 | dongsheng
# Processing Record 37 of Set 13 | providencia
# Processing Record 38 of Set 13 | korla
# Processing Record 39 of Set 13 | roald
# Processing Record 40 of Set 13 | tynda
# Processing Record 41 of Set 13 | havre-saint-pierre
# Processing Record 42 of Set 13 | westport
# Processing Record 43 of Set 13 | komoro
# Processing Record 44 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 45 of Set 13 | ngunguru
# Processing Record 46 of Set 13 | suao
# City not found. Skipping...
# Processing Record 47 of Set 13 | fare
# Processing Record 48 of Set 13 | brenham
# Processing Record 49 of Set 13 | mehriz
# Processing Record 50 of Set 13 | valparaiso
# Processing Record 1 of Set 14 | port moresby
# Processing Record 2 of Set 14 | mercedes
# Processing Record 3 of Set 14 | jalingo
# Processing Record 4 of Set 14 | harer
# Processing Record 5 of Set 14 | japoata
# Processing Record 6 of Set 14 | orsha
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 14 | terrace bay
# Processing Record 10 of Set 14 | banda aceh
# Processing Record 11 of Set 14 | nioro
# Processing Record 12 of Set 14 | udachnyy
# Processing Record 13 of Set 14 | dwarka
# Processing Record 14 of Set 14 | murgab
# Processing Record 15 of Set 14 | sinnamary
# Processing Record 16 of Set 14 | taiyuan
# Processing Record 17 of Set 14 | vieste
# Processing Record 18 of Set 14 | tazovskiy
# Processing Record 19 of Set 14 | abu dhabi
# Processing Record 20 of Set 14 | beibei
# Processing Record 21 of Set 14 | verkhnevilyuysk
# Processing Record 22 of Set 14 | ulagan
# Processing Record 23 of Set 14 | kuvshinovo
# Processing Record 24 of Set 14 | kalmunai
# Processing Record 25 of Set 14 | constantine
# Processing Record 26 of Set 14 | ozinki
# Processing Record 27 of Set 14 | rio grande
# Processing Record 28 of Set 14 | porto belo
# Processing Record 29 of Set 14 | adrar
# Processing Record 30 of Set 14 | tegh
# Processing Record 31 of Set 14 | laguna
# Processing Record 32 of Set 14 | nacala
# Processing Record 33 of Set 14 | gainesville
# Processing Record 34 of Set 14 | gisborne
# Processing Record 35 of Set 14 | tekeli
# Processing Record 36 of Set 14 | binga
# Processing Record 37 of Set 14 | tokur
# Processing Record 38 of Set 14 | kamenka
# Processing Record 39 of Set 14 | visby
# Processing Record 40 of Set 14 | alice springs
# Processing Record 41 of Set 14 | visnes
# Processing Record 42 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 14 | nemuro
# Processing Record 44 of Set 14 | vao
# Processing Record 45 of Set 14 | vila do maio
# Processing Record 46 of Set 14 | homnabad
# Processing Record 47 of Set 14 | sobolevo
# Processing Record 48 of Set 14 | juneau
# Processing Record 49 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 14 | ranau
# Processing Record 1 of Set 15 | ancud
# Processing Record 2 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 15 | durango
# Processing Record 4 of Set 15 | aklavik
# Processing Record 5 of Set 15 | nishihara
# Processing Record 6 of Set 15 | eyl
# Processing Record 7 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 8 of Set 15 | tessalit
# Processing Record 9 of Set 15 | napasar
# Processing Record 10 of Set 15 | mokhotlong
# Processing Record 11 of Set 15 | malatya
# Processing Record 12 of Set 15 | alasehir
# Processing Record 13 of Set 15 | tahe
# Processing Record 14 of Set 15 | jacareacanga
# Processing Record 15 of Set 15 | fengcheng
# Processing Record 16 of Set 15 | isangel
# Processing Record 17 of Set 15 | rivera
# Processing Record 18 of Set 15 | barmer
# Processing Record 19 of Set 15 | fairbanks
# Processing Record 20 of Set 15 | cheb
# Processing Record 21 of Set 15 | thinadhoo
# Processing Record 22 of Set 15 | costa rica
# Processing Record 23 of Set 15 | san pedro de ycuamandiyu
# Processing Record 24 of Set 15 | pocatello
# Processing Record 25 of Set 15 | guilin
# Processing Record 26 of Set 15 | kokopo
# Processing Record 27 of Set 15 | humaita
# Processing Record 28 of Set 15 | truckee
# Processing Record 29 of Set 15 | tengzhou
# Processing Record 30 of Set 15 | mittersill
# Processing Record 31 of Set 15 | dhangadhi
# Processing Record 32 of Set 15 | xai-xai
# Processing Record 33 of Set 15 | caronport
# Processing Record 34 of Set 15 | lang suan
# Processing Record 35 of Set 15 | grootfontein
# Processing Record 36 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 15 | batagay-alyta
# Processing Record 38 of Set 15 | berlevag
# Processing Record 39 of Set 15 | santa vitoria do palmar
# Processing Record 40 of Set 15 | dicabisagan
# Processing Record 41 of Set 15 | chaupal
# Processing Record 42 of Set 15 | ganzhou
# Processing Record 43 of Set 15 | marsa matruh
# Processing Record 44 of Set 15 | norrtalje
# Processing Record 45 of Set 15 | juazeiro
# Processing Record 46 of Set 15 | hokitika
# Processing Record 47 of Set 15 | havelock
# Processing Record 48 of Set 15 | san blas
# Processing Record 49 of Set 15 | diapaga
# Processing Record 50 of Set 15 | haapiti
# Processing Record 1 of Set 16 | biloela
# Processing Record 2 of Set 16 | bend
# Processing Record 3 of Set 16 | diourbel
# Processing Record 4 of Set 16 | dawson creek
# Processing Record 5 of Set 16 | krasnoselkup
# Processing Record 6 of Set 16 | bay city
# Processing Record 7 of Set 16 | varzea da palma
# Processing Record 8 of Set 16 | mahon
# Processing Record 9 of Set 16 | roros
# Processing Record 10 of Set 16 | kapuskasing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow      US  71.2906 -156.7887     -3.98        77           0
# 1         Ushuaia      AR -54.8000  -68.3000     55.02        81         100
# 2           Maloy      NO  61.9353    5.1136     42.73        75         100
# 3       Saskylakh      RU  71.9167  114.0833    -21.50       100         100
# 4    Umm Kaddadah      SD  13.6017   26.6876     78.12        10          19
# 5      Nikolskoye      RU  59.7035   30.7861     28.87        89         100
# 6     Nortelandia      BR -14.4547  -56.8028     79.23        80          97
# 7        Upington      ZA -28.4478   21.2561     88.18        18          20
# 8      Walvis Bay      NA -22.9575   14.5053     62.10        66          28
# 9  Port Elizabeth      ZA -33.9180   25.5701     67.10        84          20
#
#    Wind Speed Current Description
# 0       20.71                haze
# 1        9.22     overcast clouds
# 2        8.16     overcast clouds
# 3        3.02     overcast clouds
# 4       18.37          few clouds
# 5       19.13          light snow
# 6        5.57     overcast clouds
# 7        8.05          few clouds
# 8       11.18    scattered clouds
# 9       10.36          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
